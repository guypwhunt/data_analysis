# %%
#importing the libraries that we use in our project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.plotly as py

# %%
kill= pd.read_csv("F:\Les\Data analytic\Project\Data/PoliceKillingsUS.csv", encoding='latin-1')

# %%
kill.head(10)
# Out:
#    id                 name      date   manner_of_death       armed   age  \
# 0   3           Tim Elliot  02/01/15              shot         gun  53.0
# 1   4     Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5   John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8      Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9    Michael Rodriguez  04/01/15              shot    nail gun  39.0
# 5  11    Kenneth Joe Brown  04/01/15              shot         gun  18.0
# 6  13  Kenneth Arnold Buck  05/01/15              shot         gun  22.0
# 7  15        Brock Nichols  06/01/15              shot         gun  35.0
# 8  16        Autumn Steele  06/01/15              shot     unarmed  34.0
# 9  17      Leslie Sapp III  06/01/15              shot  toy weapon  47.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
# 5      M    W        Guthrie    OK                    False       attack
# 6      M    H       Chandler    AZ                    False       attack
# 7      M    W        Assaria    KS                    False       attack
# 8      F    W     Burlington    IA                    False        other
# 9      M    B      Knoxville    PA                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False
# 5  Not fleeing        False
# 6          Car        False
# 7  Not fleeing        False
# 8  Not fleeing         True
# 9  Not fleeing        False

# %%
poverty_level = pd.read_csv("F:\Les\Data analytic\Project\Data/PercentagePeopleBelowPovertyLevel.csv",encoding='latin-1')

# %%
poverty_level.head(10)
# Out:
#   state            city  poverty_rate
# 0    AL          abanda     78.800003
# 1    AL       abbeville     29.100000
# 2    AL      adamsville     25.500000
# 3    AL         addison     30.700001
# 4    AL           akron     42.000000
# 5    AL       alabaster     11.200000
# 6    AL     albertville     26.700001
# 7    AL  alexander city     30.400000
# 8    AL      alexandria      9.700000
# 9    AL      aliceville     41.299999

# %%
median_house_income = pd.read_csv("F:\Les\Data analytic\Project\Data/MedianHouseholdIncome2015.csv",encoding='latin-1')

# %%
median_house_income.head(10)
# Out:
#   Geographic Area                 City Median Income
# 0              AL           Abanda CDP         11207
# 1              AL       Abbeville city         25615
# 2              AL      Adamsville city         42575
# 3              AL         Addison town         37083
# 4              AL           Akron town         21667
# 5              AL       Alabaster city         71816
# 6              AL     Albertville city         32911
# 7              AL  Alexander City city         29874
# 8              AL       Alexandria CDP         56058
# 9              AL      Aliceville city         21131

# %%
race_by_city = pd.read_csv("F:\Les\Data analytic\Project\Data/ShareRaceByCity.csv",encoding='latin-1')

# %%
race_by_city.head(20)
# Out:
#    Geographic area                 City share_white share_black  \
# 0               AL           Abanda CDP        67.2        30.2
# 1               AL       Abbeville city        54.4        41.4
# 2               AL      Adamsville city        52.3        44.9
# 3               AL         Addison town        99.1         0.1
# 4               AL           Akron town        13.2        86.5
# 5               AL       Alabaster city        79.4        13.5
# 6               AL     Albertville city        75.9         1.9
# 7               AL  Alexander City city        62.2          32
# 8               AL       Alexandria CDP        87.4        10.2
# 9               AL      Aliceville city        22.6        74.9
# 10              AL         Allgood town        79.6         0.6
# 11              AL         Altoona town        95.8         1.7
# 12              AL       Andalusia city        70.5        25.9
# 13              AL        Anderson town        97.9           0
# 14              AL        Anniston city        44.7        51.5
# 15              AL            Arab city        96.6         0.1
# 16              AL         Ardmore town        94.3         1.9
# 17              AL            Argo town        94.1         3.6
# 18              AL          Ariton town        78.3        19.2
# 19              AL           Arley town        94.4           0
#
#    share_native_american share_asian share_hispanic
# 0                      0           0            1.6
# 1                    0.1           1            3.1
# 2                    0.5         0.3            2.3
# 3                      0         0.1            0.4
# 4                      0           0            0.3
# 5                    0.4         0.9              9
# 6                    0.8         0.5           27.9
# 7                    0.2         0.9            4.8
# 8                    0.3         0.5            0.9
# 9                    0.1           0            1.2
# 10                   0.3         0.6           49.4
# 11                   0.2         0.2            1.1
# 12                   0.4           1            1.9
# 13                   0.4           0            0.7
# 14                   0.3         0.8            2.7
# 15                   0.6         0.7            1.7
# 16                   0.8         0.9            1.3
# 17                   0.4         0.3            0.5
# 18                     0         0.1              6
# 19                   0.6         0.3            1.4

# %%
percentage_complete_highschool = pd.read_csv("F:\Les\Data analytic\Project\Data/PercentOver25CompletedHighSchool.csv",encoding='latin-1')

# %%
percentage_complete_highschool.head(10)
# Out:
#   Geographic Area                 City percent_completed_hs
# 0              AL           Abanda CDP                 21.2
# 1              AL       Abbeville city                 69.1
# 2              AL      Adamsville city                 78.9
# 3              AL         Addison town                 81.4
# 4              AL           Akron town                 68.6
# 5              AL       Alabaster city                 89.3
# 6              AL     Albertville city                 72.7
# 7              AL  Alexander City city                 78.1
# 8              AL       Alexandria CDP                 88.8
# 9              AL      Aliceville city                 74.3

# %%
kill.drop_duplicates() #removing duplicates
# Out:
#         id                              name      date   manner_of_death  \
# 0        3                        Tim Elliot  02/01/15              shot
# 1        4                  Lewis Lee Lembke  02/01/15              shot
# 2        5                John Paul Quintero  03/01/15  shot and Tasered
# 3        8                   Matthew Hoffman  04/01/15              shot
# 4        9                 Michael Rodriguez  04/01/15              shot
# 5       11                 Kenneth Joe Brown  04/01/15              shot
# 6       13               Kenneth Arnold Buck  05/01/15              shot
# 7       15                     Brock Nichols  06/01/15              shot
# 8       16                     Autumn Steele  06/01/15              shot
# 9       17                   Leslie Sapp III  06/01/15              shot
# 10      19                    Patrick Wetter  06/01/15  shot and Tasered
# 11      21                         Ron Sneed  07/01/15              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  07/01/15              shot
# 13      25            Nicholas Ryan Brickman  07/01/15              shot
# 14      27  Omarr Julian Maximillian Jackson  07/01/15              shot
# 15      29                     Loren Simpson  08/01/15              shot
# 16      32               James Dudley Barker  08/01/15              shot
# 17      36               Artago Damon Howard  08/01/15              shot
# 18      37                      Thomas Hamby  08/01/15              shot
# 19      38                     Jimmy Foreman  09/01/15              shot
# 20     325                     Andy Martinez  09/01/15              shot
# 21      42                       Tommy Smith  11/01/15              shot
# 22      43                    Brian  Barbosa  11/01/15              shot
# 23      45                 Salvador Figueroa  11/01/15  shot and Tasered
# 24      46               John Edward O'Keefe  13/01/15              shot
# 25      48                 Richard McClendon  13/01/15              shot
# 26      49                     Marcus Golden  14/01/15              shot
# 27      50                    Michael Goebel  14/01/15              shot
# 28      51                      Mario Jordan  14/01/15              shot
# 29      52                  Talbot Schroeder  14/01/15              shot
# ...    ...                               ...       ...               ...
# 2505  2790                 Anthony Benavidez  19/07/17              shot
# 2506  2791                    Farhad Jabbari  19/07/17              shot
# 2507  2792                    Joshua Daniels  20/07/17              shot
# 2508  2793                    Isaiah Perkins  20/07/17              shot
# 2509  2794                      Yahir Breito  21/07/17              shot
# 2510  2797                 Vicente Velasquez  21/07/17              shot
# 2511  2795                      Walter Lynde  23/07/17              shot
# 2512  2796                 Michael Caponigro  23/07/17              shot
# 2513  2799            Ismael Lopez Rodriguez  23/07/17              shot
# 2514  2800                Kyle Scott Rushing  23/07/17              shot
# 2515  2798                    Jerrod Kershaw  24/07/17              shot
# 2516  2801            Alexander J. Schoessel  25/07/17              shot
# 2517  2802             Michael Joseph Harris  25/07/17              shot
# 2518  2803                 Moises Balladares  25/07/17              shot
# 2519  2805                       Aries Clark  25/07/17              shot
# 2520  2804                             TK TK  26/07/17              shot
# 2521  2806                             TK TK  26/07/17              shot
# 2522  2807                        Susan Teel  26/07/17              shot
# 2523  2808                 Kesharn K. Burney  26/07/17              shot
# 2524  2816        Jerauld Phillip Hammond II  27/07/17              shot
# 2525  2820                  Deltra Henderson  27/07/17              shot
# 2526  2809           Sergio Velasco-Martinez  27/07/17              shot
# 2527  2811                    Matthew Folden  27/07/17              shot
# 2528  2812                Alejandro Alvarado  27/07/17              shot
# 2529  2819                  Brian J. Skinner  28/07/17              shot
# 2530  2822                  Rodney E. Jacobs  28/07/17              shot
# 2531  2813                             TK TK  28/07/17              shot
# 2532  2818                Dennis W. Robinson  29/07/17              shot
# 2533  2817                     Isaiah Tucker  31/07/17              shot
# 2534  2815                      Dwayne Jeune  31/07/17              shot
#
#              armed   age gender race             city state  \
# 0              gun  53.0      M    A          Shelton    WA
# 1              gun  47.0      M    W            Aloha    OR
# 2          unarmed  23.0      M    H          Wichita    KS
# 3       toy weapon  32.0      M    W    San Francisco    CA
# 4         nail gun  39.0      M    H            Evans    CO
# 5              gun  18.0      M    W          Guthrie    OK
# 6              gun  22.0      M    H         Chandler    AZ
# 7              gun  35.0      M    W          Assaria    KS
# 8          unarmed  34.0      F    W       Burlington    IA
# 9       toy weapon  47.0      M    B        Knoxville    PA
# 10           knife  25.0      M    W         Stockton    CA
# 11             gun  31.0      M    B         Freeport    TX
# 12           knife  41.0      M    B         Columbus    OH
# 13             gun  30.0      M    W       Des Moines    IA
# 14             gun  37.0      M    B      New Orleans    LA
# 15         vehicle  28.0      M    W          Huntley    MT
# 16          shovel  42.0      M    W   Salt Lake City    UT
# 17         unarmed  36.0      M    B           Strong    AR
# 18             gun  49.0      M    W         Syracuse    UT
# 19             gun  71.0      M    W          England    AR
# 20             gun  33.0      M    H          El Paso    TX
# 21             gun  39.0      M    W           Arcola    IL
# 22             gun  23.0      M    H       South Gate    CA
# 23             gun  29.0      M    H  North Las Vegas    NV
# 24             gun  34.0      M    W      Albuquerque    NM
# 25           knife  43.0      M    W       Jourdanton    TX
# 26         vehicle  24.0      M    B         St. Paul    MN
# 27         vehicle  29.0      M    W  Franklin County    MO
# 28             gun  34.0      M    B       Chesapeake    VA
# 29           knife  75.0      M    W       Old Bridge    NJ
# ...            ...   ...    ...  ...              ...   ...
# 2505         knife  24.0      M  NaN         Santa Fe    NM
# 2506       unarmed  38.0      M  NaN          Saginaw    MI
# 2507           gun  52.0      M    W           Neosho    MO
# 2508           gun  27.0      M    B        St. Louis    MO
# 2509         knife  22.0      M  NaN        Santa Ana    CA
# 2510           gun  42.0      M  NaN          Mission    TX
# 2511    toy weapon  49.0      M    W          Spencer    MA
# 2512           gun  59.0      M    W       Eau Claire    WI
# 2513           gun  41.0      M    H        Southaven    MS
# 2514         knife  34.0      M    W            Chico    CA
# 2515           gun  31.0      M    W        St. Louis    MO
# 2516            ax  23.0      M    W         Richmond    VA
# 2517           gun  28.0      M    W     Jacksonville    FL
# 2518           gun  33.0      M  NaN         Avondale    AZ
# 2519  undetermined  16.0      M    B           Marion    AR
# 2520           gun  35.0      M  NaN          Phoenix    AZ
# 2521           gun   NaN      M  NaN      San Antonio    TX
# 2522         knife  62.0      F  NaN       Vero Beach    FL
# 2523       vehicle  25.0      M    B           Dayton    OH
# 2524           gun  46.0      M  NaN      Los Angeles    CA
# 2525           gun  39.0      M    B            Homer    LA
# 2526  blunt object  25.0      M  NaN           Avenal    CA
# 2527         knife  31.0      M  NaN        Wenatchee    WA
# 2528         knife   NaN      M    H       Chowchilla    CA
# 2529         knife  32.0      M  NaN        Glenville    NY
# 2530           gun  31.0      M  NaN      Kansas City    MO
# 2531       vehicle   NaN      M  NaN      Albuquerque    NM
# 2532           gun  48.0      M  NaN            Melba    ID
# 2533       vehicle  28.0      M    B          Oshkosh    WI
# 2534         knife  32.0      M    B         Brooklyn    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 2505                    False         other  Not fleeing        False
# 2506                    False        attack  Not fleeing        False
# 2507                    False        attack  Not fleeing        False
# 2508                    False        attack          Car        False
# 2509                    False         other  Not fleeing        False
# 2510                    False        attack         Foot        False
# 2511                    False        attack          Car        False
# 2512                     True        attack  Not fleeing        False
# 2513                    False        attack  Not fleeing        False
# 2514                    False        attack  Not fleeing         True
# 2515                     True        attack          Car        False
# 2516                     True         other         Foot        False
# 2517                    False        attack          Car        False
# 2518                     True        attack  Not fleeing        False
# 2519                    False  undetermined  Not fleeing        False
# 2520                    False        attack        Other        False
# 2521                    False        attack  Not fleeing        False
# 2522                     True        attack  Not fleeing        False
# 2523                    False        attack          Car        False
# 2524                    False         other  Not fleeing        False
# 2525                    False        attack          Car        False
# 2526                    False        attack  Not fleeing        False
# 2527                    False         other  Not fleeing        False
# 2528                    False        attack  Not fleeing        False
# 2529                     True         other  Not fleeing        False
# 2530                    False        attack  Not fleeing        False
# 2531                    False        attack          Car        False
# 2532                    False        attack          Car        False
# 2533                    False        attack          Car         True
# 2534                     True        attack  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
poverty_level.drop_duplicates() #removing the duplicates
# Out:
#       state                city  poverty_rate
# 0        AL              abanda     78.800003
# 1        AL           abbeville     29.100000
# 2        AL          adamsville     25.500000
# 3        AL             addison     30.700001
# 4        AL               akron     42.000000
# 5        AL           alabaster     11.200000
# 6        AL         albertville     26.700001
# 7        AL      alexander city     30.400000
# 8        AL          alexandria      9.700000
# 9        AL          aliceville     41.299999
# 10       AL             allgood     27.700001
# 11       AL             altoona     27.500000
# 12       AL           andalusia     24.500000
# 13       AL            anderson     13.800000
# 14       AL            anniston     31.700001
# 15       AL                arab     16.700001
# 16       AL             ardmore     19.100000
# 17       AL                argo      8.600000
# 18       AL              ariton     37.599998
# 19       AL               arley     31.600000
# 20       AL             ashford     18.799999
# 21       AL             ashland     22.400000
# 22       AL            ashville     28.299999
# 23       AL              athens     13.000000
# 24       AL              atmore     24.700001
# 25       AL             attalla     20.299999
# 26       AL              auburn     31.799999
# 27       AL        autaugaville     24.100000
# 28       AL                avon     22.200001
# 29       AL                axis      6.800000
# ...     ...                 ...           ...
# 29298    WY       south greeley     17.100000
# 29299    WY          south park      0.000000
# 29300    WY   star valley ranch      4.800000
# 29301    WY               story      9.400000
# 29302    WY            sundance      4.700000
# 29303    WY            superior     14.300000
# 29305    WY              taylor      0.000000
# 29306    WY           ten sleep     14.800000
# 29307    WY       teton village      0.000000
# 29308    WY              thayne     14.100000
# 29309    WY         thermopolis     13.400000
# 29310    WY          torrington     20.900000
# 29311    WY         turnerville      0.000000
# 29312    WY               upton     15.500000
# 29313    WY                urie      2.200000
# 29314    WY         van tassell     42.900002
# 29315    WY             veteran      0.000000
# 29316    WY          vista west      3.300000
# 29317    WY           wamsutter      6.400000
# 29318    WY          warren afb      2.200000
# 29319    WY              washam      0.000000
# 29320    WY     westview circle    100.000000
# 29321    WY           wheatland     12.000000
# 29322    WY             whiting      0.000000
# 29323    WY              wilson      2.900000
# 29324    WY  woods landing-jelm     18.600000
# 29325    WY             worland     15.300000
# 29326    WY              wright      5.900000
# 29327    WY               yoder      5.400000
# 29328    WY           y-o ranch      0.000000
#
# [29127 rows x 3 columns]

# %%
median_house_income.drop_duplicates() #removing duplicates
# Out:
#       Geographic Area                    City Median Income
# 0                  AL              Abanda CDP         11207
# 1                  AL          Abbeville city         25615
# 2                  AL         Adamsville city         42575
# 3                  AL            Addison town         37083
# 4                  AL              Akron town         21667
# 5                  AL          Alabaster city         71816
# 6                  AL        Albertville city         32911
# 7                  AL     Alexander City city         29874
# 8                  AL          Alexandria CDP         56058
# 9                  AL         Aliceville city         21131
# 10                 AL            Allgood town         42009
# 11                 AL            Altoona town         27566
# 12                 AL          Andalusia city         31968
# 13                 AL           Anderson town         34792
# 14                 AL           Anniston city         29681
# 15                 AL               Arab city         40292
# 16                 AL            Ardmore town         35670
# 17                 AL               Argo town         57212
# 18                 AL             Ariton town         24286
# 19                 AL              Arley town         28750
# 20                 AL            Ashford town         42704
# 21                 AL            Ashland town         31438
# 22                 AL           Ashville city         40547
# 23                 AL             Athens city         47542
# 24                 AL             Atmore city         26775
# 25                 AL            Attalla city         37191
# 26                 AL             Auburn city         38342
# 27                 AL       Autaugaville town         24833
# 28                 AL               Avon town         40417
# 29                 AL                Axis CDP         55750
# ...               ...                     ...           ...
# 29292              WY          South Park CDP         97286
# 29293              WY  Star Valley Ranch town         70326
# 29294              WY               Story CDP         45561
# 29295              WY           Sundance town         56452
# 29296              WY           Superior town         55000
# 29297              WY          Table Rock CDP           NaN
# 29298              WY              Taylor CDP         77917
# 29299              WY          Ten Sleep town         51250
# 29300              WY       Teton Village CDP           NaN
# 29301              WY             Thayne town         41250
# 29302              WY        Thermopolis town         43438
# 29303              WY         Torrington city         40911
# 29304              WY         Turnerville CDP         40795
# 29305              WY              Upton town         61333
# 29306              WY                Urie CDP         89044
# 29307              WY        Van Tassell town           NaN
# 29308              WY             Veteran CDP           NaN
# 29309              WY          Vista West CDP        101667
# 29310              WY          Wamsutter town         80179
# 29311              WY          Warren AFB CDP         50982
# 29312              WY              Washam CDP           NaN
# 29313              WY     Westview Circle CDP           NaN
# 29314              WY          Wheatland town         34984
# 29315              WY             Whiting CDP           NaN
# 29316              WY              Wilson CDP         94792
# 29317              WY  Woods Landing-Jelm CDP           NaN
# 29318              WY            Worland city         41523
# 29319              WY             Wright town         77114
# 29320              WY              Yoder town         37500
# 29321              WY           Y-O Ranch CDP           NaN
#
# [29322 rows x 3 columns]

# %%
race_by_city.drop_duplicates()
# Out:
#       Geographic area                    City share_white share_black  \
# 0                  AL              Abanda CDP        67.2        30.2
# 1                  AL          Abbeville city        54.4        41.4
# 2                  AL         Adamsville city        52.3        44.9
# 3                  AL            Addison town        99.1         0.1
# 4                  AL              Akron town        13.2        86.5
# 5                  AL          Alabaster city        79.4        13.5
# 6                  AL        Albertville city        75.9         1.9
# 7                  AL     Alexander City city        62.2          32
# 8                  AL          Alexandria CDP        87.4        10.2
# 9                  AL         Aliceville city        22.6        74.9
# 10                 AL            Allgood town        79.6         0.6
# 11                 AL            Altoona town        95.8         1.7
# 12                 AL          Andalusia city        70.5        25.9
# 13                 AL           Anderson town        97.9           0
# 14                 AL           Anniston city        44.7        51.5
# 15                 AL               Arab city        96.6         0.1
# 16                 AL            Ardmore town        94.3         1.9
# 17                 AL               Argo town        94.1         3.6
# 18                 AL             Ariton town        78.3        19.2
# 19                 AL              Arley town        94.4           0
# 20                 AL            Ashford town          79        19.5
# 21                 AL            Ashland town        71.5        24.1
# 22                 AL           Ashville city        75.8        20.3
# 23                 AL             Athens city          73        17.5
# 24                 AL             Atmore city          40        55.6
# 25                 AL            Attalla city        81.5        12.7
# 26                 AL             Auburn city        75.1        16.5
# 27                 AL       Autaugaville town        31.3        66.8
# 28                 AL               Avon town        94.7         1.8
# 29                 AL                Axis CDP        66.8        26.9
# ...               ...                     ...         ...         ...
# 29238              WY          South Park CDP          94         0.1
# 29239              WY  Star Valley Ranch town        96.3         0.1
# 29240              WY               Story CDP        97.9           0
# 29241              WY           Sundance town        97.8         0.2
# 29242              WY           Superior town        91.4         0.6
# 29243              WY          Table Rock CDP         (X)         (X)
# 29244              WY              Taylor CDP        87.8           0
# 29245              WY          Ten Sleep town        97.3           0
# 29246              WY       Teton Village CDP        93.9         0.6
# 29247              WY             Thayne town        91.5           0
# 29248              WY        Thermopolis town        96.4         0.3
# 29249              WY         Torrington city        93.2           1
# 29250              WY         Turnerville CDP          99           0
# 29251              WY              Upton town        95.6         0.2
# 29252              WY                Urie CDP        99.6           0
# 29253              WY        Van Tassell town         100           0
# 29254              WY             Veteran CDP          87           0
# 29255              WY          Vista West CDP        97.1           0
# 29256              WY          Wamsutter town        82.7         0.7
# 29257              WY          Warren AFB CDP        79.1         7.6
# 29258              WY              Washam CDP         100           0
# 29259              WY     Westview Circle CDP         100           0
# 29260              WY          Wheatland town        95.1         0.1
# 29261              WY             Whiting CDP        96.4           0
# 29262              WY              Wilson CDP        97.5         0.2
# 29263              WY  Woods Landing-Jelm CDP        95.9           0
# 29264              WY            Worland city        89.9         0.3
# 29265              WY             Wright town        94.5         0.1
# 29266              WY              Yoder town        97.4           0
# 29267              WY           Y-O Ranch CDP        92.8         1.5
#
#       share_native_american share_asian share_hispanic
# 0                         0           0            1.6
# 1                       0.1           1            3.1
# 2                       0.5         0.3            2.3
# 3                         0         0.1            0.4
# 4                         0           0            0.3
# 5                       0.4         0.9              9
# 6                       0.8         0.5           27.9
# 7                       0.2         0.9            4.8
# 8                       0.3         0.5            0.9
# 9                       0.1           0            1.2
# 10                      0.3         0.6           49.4
# 11                      0.2         0.2            1.1
# 12                      0.4           1            1.9
# 13                      0.4           0            0.7
# 14                      0.3         0.8            2.7
# 15                      0.6         0.7            1.7
# 16                      0.8         0.9            1.3
# 17                      0.4         0.3            0.5
# 18                        0         0.1              6
# 19                      0.6         0.3            1.4
# 20                      0.2         0.2            0.8
# 21                      0.3         0.7            5.7
# 22                      0.2         0.3            3.8
# 23                      0.6         0.9            8.8
# 24                      1.8         0.3            1.8
# 25                      0.4         0.5            4.7
# 26                      0.3         5.3            2.9
# 27                      0.2           0            0.8
# 28                      1.8           0            1.3
# 29                      3.2         0.1            0.9
# ...                     ...         ...            ...
# 29238                   0.2         0.5            5.9
# 29239                   0.8         0.6            3.4
# 29240                   0.7         0.2            1.7
# 29241                   0.8           0            1.2
# 29242                   1.8         0.6           12.8
# 29243                   (X)         (X)            (X)
# 29244                   1.1           0           13.3
# 29245                   0.8         0.4            0.8
# 29246                   0.3         1.2            3.9
# 29247                     0         1.1            9.3
# 29248                   0.9         0.5            2.2
# 29249                   0.9         0.5           11.3
# 29250                   0.5           0            0.5
# 29251                   1.7         0.5            2.3
# 29252                     0           0            1.1
# 29253                     0           0              0
# 29254                   8.7           0              0
# 29255                   0.3         0.1            1.9
# 29256                   2.9           0           19.7
# 29257                   0.7         2.3           11.3
# 29258                     0           0            3.9
# 29259                     0           0            1.9
# 29260                   0.4         0.7            7.4
# 29261                     0           0              6
# 29262                   0.3         0.8            1.8
# 29263                     0         2.1              0
# 29264                   1.3         0.6           16.6
# 29265                   1.4         0.2            6.2
# 29266                     0           0              4
# 29267                   2.6           0           11.8
#
# [29268 rows x 7 columns]

# %%
percentage_complete_highschool.drop_duplicates()
# Out:
#       Geographic Area                    City percent_completed_hs
# 0                  AL              Abanda CDP                 21.2
# 1                  AL          Abbeville city                 69.1
# 2                  AL         Adamsville city                 78.9
# 3                  AL            Addison town                 81.4
# 4                  AL              Akron town                 68.6
# 5                  AL          Alabaster city                 89.3
# 6                  AL        Albertville city                 72.7
# 7                  AL     Alexander City city                 78.1
# 8                  AL          Alexandria CDP                 88.8
# 9                  AL         Aliceville city                 74.3
# 10                 AL            Allgood town                 48.1
# 11                 AL            Altoona town                 66.9
# 12                 AL          Andalusia city                 81.1
# 13                 AL           Anderson town                 85.7
# 14                 AL           Anniston city                 79.8
# 15                 AL               Arab city                 87.6
# 16                 AL            Ardmore town                 77.7
# 17                 AL               Argo town                 87.5
# 18                 AL             Ariton town                 71.3
# 19                 AL              Arley town                 80.6
# 20                 AL            Ashford town                 83.5
# 21                 AL            Ashland town                 77.9
# 22                 AL           Ashville city                 77.6
# 23                 AL             Athens city                 83.4
# 24                 AL             Atmore city                 73.7
# 25                 AL            Attalla city                   76
# 26                 AL             Auburn city                 94.3
# 27                 AL       Autaugaville town                 71.2
# 28                 AL               Avon town                 82.8
# 29                 AL                Axis CDP                 79.9
# ...               ...                     ...                  ...
# 29299              WY          South Park CDP                   99
# 29300              WY  Star Valley Ranch town                 88.5
# 29301              WY               Story CDP                 93.9
# 29302              WY           Sundance town                 93.1
# 29303              WY           Superior town                 91.6
# 29304              WY          Table Rock CDP                    -
# 29305              WY              Taylor CDP                  100
# 29306              WY          Ten Sleep town                 84.4
# 29307              WY       Teton Village CDP                  100
# 29308              WY             Thayne town                 86.5
# 29309              WY        Thermopolis town                 92.5
# 29310              WY         Torrington city                 90.6
# 29311              WY         Turnerville CDP                  100
# 29312              WY              Upton town                 92.5
# 29313              WY                Urie CDP                   98
# 29314              WY        Van Tassell town                  100
# 29315              WY             Veteran CDP                   50
# 29316              WY          Vista West CDP                 93.1
# 29317              WY          Wamsutter town                 93.3
# 29318              WY          Warren AFB CDP                 96.6
# 29319              WY              Washam CDP                  100
# 29320              WY     Westview Circle CDP                  100
# 29321              WY          Wheatland town                 92.7
# 29322              WY             Whiting CDP                  100
# 29323              WY              Wilson CDP                  100
# 29324              WY  Woods Landing-Jelm CDP                  100
# 29325              WY            Worland city                 85.6
# 29326              WY             Wright town                 89.2
# 29327              WY              Yoder town                 79.4
# 29328              WY           Y-O Ranch CDP                  100
#
# [29329 rows x 3 columns]

# %%
kill_miss_values = kill.isnull().sum() #see the Nan values of the kill DataFrame
kill_miss_values[kill_miss_values > 0]
# Out:
# armed      9
# age       77
# race     195
# flee      65
# dtype: int64

# %%
kill.armed = kill.armed.fillna('unknown') #filling the armed Nan values by 'unknown'

# %%
kill['age'].fillna((kill['age'].mean()), inplace=True) #filling the age Nan values by the average

# %%
kill.dropna(subset=['race'],how='all', inplace = True) #drop the rows that have Nan values in 'race' attribute

# %%
kill.drop('flee',axis=1,inplace=True) #droping the 'flee' attribute

# %%
kill['name'].replace(['TK TK'],'Unknown',inplace = True) #Replacing the rows that have 'TK TK' in 'name' attribute bt 'Unknown'

# %%
poverty_level_miss_values = poverty_level.isnull().sum()
poverty_level_miss_values[poverty_level_miss_values > 0]
poverty_level.head()
# Out:
#   state        city  poverty_rate
# 0    AL      abanda     78.800003
# 1    AL   abbeville     29.100000
# 2    AL  adamsville     25.500000
# 3    AL     addison     30.700001
# 4    AL       akron     42.000000

# %%
poverty_level = poverty_level [poverty_level.iloc[:,2] != '-'] #removing rows that have '-' in poverty_rate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-8b970b954374> in <module>
# ----> 1 poverty_level = poverty_level [poverty_level.iloc[:,2] != '-'] #removing rows that have '-' in poverty_rate
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1167                     result = method(y)
#    1168                 if result is NotImplemented:
# -> 1169                     raise TypeError("invalid type comparison")
#    1170             else:
#    1171                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
median_house_income_miss_values = median_house_income.isnull().sum()#see the Nan values of the median_house_income DataFrame
median_house_income_miss_values[median_house_income_miss_values > 0]
# Out:
# Median Income    51
# dtype: int64

# %%
median_house_income.dropna(subset=['Median Income'],how='all', inplace = True) #dropping the rows that have Nan values in median income

# %%
median_house_income = median_house_income [median_house_income.iloc[:,2] != '(X)'] #drop (X) and '-' values
median_house_income = median_house_income [median_house_income.iloc[:,2] != '-']
median_house_income.iloc[:,2] = median_house_income.iloc[:,2].replace('2,500-',2500) #replacing median income which is -2500 with 2500
median_house_income.iloc[:,2] = median_house_income.iloc[:,2].replace('250,000+',250000)

# %%
race_by_city_miss_values = race_by_city.isnull().sum()#
race_by_city_miss_values[race_by_city_miss_values >0 ]
# Out:
# Series([], dtype: int64)

# %%
race_by_city = race_by_city [race_by_city.iloc[:,2] != '(X)']
race_by_city = race_by_city [race_by_city.iloc[:,3] != '(X)']
race_by_city = race_by_city [race_by_city.iloc[:,4] != '(X)']
race_by_city = race_by_city [race_by_city.iloc[:,5] != '(X)']
race_by_city = race_by_city [race_by_city.iloc[:,6] != '(X)']

# %%
race_by_city = race_by_city [race_by_city.iloc[:,2] != '-']
race_by_city = race_by_city [race_by_city.iloc[:,3] != '-']
race_by_city = race_by_city [race_by_city.iloc[:,4] != '-']
race_by_city = race_by_city [race_by_city.iloc[:,5] != '-']
race_by_city = race_by_city [race_by_city.iloc[:,6] != '-']

# %%
percentage_complete_highschool_miss_values = percentage_complete_highschool.isnull().sum()
percentage_complete_highschool_miss_values[percentage_complete_highschool_miss_values > 0]
# Out:
# Series([], dtype: int64)

# %%
percentage_complete_highschool = percentage_complete_highschool [percentage_complete_highschool.iloc[:,2] != '-']

# %%
kill.armed.unique()
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'vehicle',
#        'shovel', 'hammer', 'hatchet', 'undetermined', 'sword', 'machete',
#        'box cutter', 'metal object', 'screwdriver', 'lawn mower blade',
#        'flagpole', 'guns and explosives', 'cordless drill', 'metal pole',
#        'Taser', 'metal pipe', 'metal hand tool', 'blunt object',
#        'metal stick', 'sharp object', 'meat cleaver', 'unknown',
#        'carjack', 'chain', "contractor's level", 'unknown weapon',
#        'stapler', 'crossbow', 'bean-bag gun',
#        'baseball bat and fireplace poker', 'straight edge razor',
#        'gun and knife', 'ax', 'brick', 'baseball bat', 'hand torch',
#        'chain saw', 'garden tool', 'scissors', 'pole', 'pick-axe',
#        'flashlight', 'spear', 'pitchfork', 'hatchet and gun', 'rock',
#        'piece of wood', 'bayonet', 'pipe', 'glass shard', 'motorcycle',
#        'metal rake', 'baton', 'crowbar', 'oar', 'machete and gun',
#        'air conditioner', 'pole and knife', 'beer bottle',
#        'baseball bat and bottle', 'fireworks', 'pen'], dtype=object)

# %%
kill.armed = kill.armed.str.lower() #making the armed column to lower

# %%
kill.armed = kill.armed.mask(kill.armed == 'undetermined','unknown') #replacing undeterminde and unknown weapon by unknown
kill.armed = kill.armed.mask(kill.armed == 'unknown weapon','unknown')

# %%
kill.armed= kill.armed.mask(kill.armed == 'guns and explosives','gun')#replacing guns and explosives by gun
kill.armed= kill.armed.mask(kill.armed == 'gun and knife','gun') #replacing gun and knife by gun
kill.armed= kill.armed.mask(kill.armed == 'hatchet and gun','gun')#replacing hatchet and gun by gun
kill.armed= kill.armed.mask(kill.armed == 'machete and gun','gun')#replacing machete and gun by gun

# %%
kill.armed = kill.armed.mask(kill.armed == 'sword','knife')
kill.armed = kill.armed.mask(kill.armed == 'machete','knife')
kill.armed = kill.armed.mask(kill.armed == 'box cutter','knife')
kill.armed = kill.armed.mask(kill.armed == 'bayonet','knife')
kill.armed = kill.armed.mask(kill.armed == 'meat cleaver','knife')
kill.armed = kill.armed.mask(kill.armed == 'pole and knife','knife')
kill.armed = kill.armed.mask(kill.armed == 'lawn mower blade','knife')
kill.armed = kill.armed.mask(kill.armed == 'straight edge razor','knife')

# %%
kill.armed = kill.armed.mask(kill.armed == 'motorcycle','vehicle')

# %%
kill.armed = kill.armed.mask (kill.armed == 'ax','hatchet')

# %%
kill.armed = kill.armed.mask(kill.armed == 'flagpole','metal object')
kill.armed = kill.armed.mask(kill.armed == 'metal pipe','metal object')
kill.armed = kill.armed.mask(kill.armed == 'metal hand tool','metal object')
kill.armed = kill.armed.mask(kill.armed == 'metal pole','metal object')
kill.armed = kill.armed.mask(kill.armed == 'metal stick','metal object')

# %%
kill.armed = kill.armed.mask(kill.armed == 'brick','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'baseball bat','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'pole','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'rock','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'piece of wood','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'baton','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'oar','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'baseball bat and fireplace poker','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'hammer','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'baseball bat and bottle','blunt object')
kill.armed = kill.armed.mask(kill.armed == 'pipe','blunt object')

# %%
kill.race.unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', 'N'], dtype=object)

# %%
kill.drop('id',axis=1,inplace=True) #dropping the id attribute

# %%
kill.columns =[ 'name','date','manner_of_death','armed','age','gender','race','city','state','mental_illness','threat',
               'body_camera'] #renaming the kill DataFrame column

# %%
kill.head()
# Out:
#                  name      date   manner_of_death       armed   age gender  \
# 0          Tim Elliot  02/01/15              shot         gun  53.0      M
# 1    Lewis Lee Lembke  02/01/15              shot         gun  47.0      M
# 2  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman  04/01/15              shot  toy weapon  32.0      M
# 4   Michael Rodriguez  04/01/15              shot    nail gun  39.0      M
#
#   race           city state  mental_illness  threat  body_camera
# 0    A        Shelton    WA            True  attack        False
# 1    W          Aloha    OR           False  attack        False
# 2    H        Wichita    KS           False   other        False
# 3    W  San Francisco    CA            True  attack        False
# 4    H          Evans    CO           False  attack        False

# %%
poverty_level.columns= ['state','city','poverty_rate'] #renaming columns

# %%
percentage_complete_highschool.head()
# Out:
#   Geographic Area             City percent_completed_hs
# 0              AL       Abanda CDP                 21.2
# 1              AL   Abbeville city                 69.1
# 2              AL  Adamsville city                 78.9
# 3              AL     Addison town                 81.4
# 4              AL       Akron town                 68.6

# %%
median_house_income.columns = ['state','city','median_income'] #Rename columns
median_house_income .head()
# Out:
#   state             city median_income
# 0    AL       Abanda CDP         11207
# 1    AL   Abbeville city         25615
# 2    AL  Adamsville city         42575
# 3    AL     Addison town         37083
# 4    AL       Akron town         21667

# %%
race_by_city.columns= ['state','city','white','black','native_american','asian','hispanic']
race_by_city.head()
# Out:
#   state             city white black native_american asian hispanic
# 0    AL       Abanda CDP  67.2  30.2               0     0      1.6
# 1    AL   Abbeville city  54.4  41.4             0.1     1      3.1
# 2    AL  Adamsville city  52.3  44.9             0.5   0.3      2.3
# 3    AL     Addison town  99.1   0.1               0   0.1      0.4
# 4    AL       Akron town  13.2  86.5               0     0      0.3

# %%
percentage_complete_highschool.columns = ['state','city','completed_hs']
percentage_complete_highschool.head()
# Out:
#   state             city completed_hs
# 0    AL       Abanda CDP         21.2
# 1    AL   Abbeville city         69.1
# 2    AL  Adamsville city         78.9
# 3    AL     Addison town         81.4
# 4    AL       Akron town         68.6

# %%
kill.city = kill.city.str.lower() #making city to lowercase
poverty_level.city = poverty_level.city.str.lower()
median_house_income.city = median_house_income.city.str.lower()
race_by_city.city = race_by_city.city.str.lower()
percentage_complete_highschool.city = percentage_complete_highschool.city.str.lower()

# %%
kill.date = pd.to_datetime(kill.date,dayfirst=True) #ensure that date column is of date type
kill.head()
# Out:
#                  name       date   manner_of_death       armed   age gender  \
# 0          Tim Elliot 2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#   race           city state  mental_illness  threat  body_camera
# 0    A        shelton    WA            True  attack        False
# 1    W          aloha    OR           False  attack        False
# 2    H        wichita    KS           False   other        False
# 3    W  san francisco    CA            True  attack        False
# 4    H          evans    CO           False  attack        False

# %%
poverty_level.poverty_rate = pd.to_numeric(poverty_level.poverty_rate,downcast='float') 
#ensure that date column is of float
median_house_income.head()
# Out:
#   state             city median_income
# 0    AL       Abanda CDP         11207
# 1    AL   Abbeville city         25615
# 2    AL  Adamsville city         42575
# 3    AL     Addison town         37083
# 4    AL       Akron town         21667

# %%
median_house_income.median_income = pd.to_numeric(median_house_income.median_income,downcast='float')

# %%
race_by_city.white = pd.to_numeric(race_by_city.white, downcast='float')
race_by_city.black = pd.to_numeric(race_by_city.black, downcast='float')
race_by_city.native_american = pd.to_numeric(race_by_city.native_american, downcast='float')
race_by_city.asian = pd.to_numeric(race_by_city.asian, downcast='float')
race_by_city.hispanic = pd.to_numeric(race_by_city.hispanic, downcast='float')

# %%
percentage_complete_highschool.completed_hs = pd.to_numeric(percentage_complete_highschool.completed_hs, downcast='float')
percentage_complete_highschool.head()
# Out:
#   state             city  completed_hs
# 0    AL       abanda cdp     21.200001
# 1    AL   abbeville city     69.099998
# 2    AL  adamsville city     78.900002
# 3    AL     addison town     81.400002
# 4    AL       akron town     68.599998

# %%
#showing the poverty rate of states:
area_list = list(poverty_level['state'].unique())

# %%
kill.head()
# Out:
#                  name       date   manner_of_death       armed   age gender  \
# 0          Tim Elliot 2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#   race           city state  mental_illness  threat  body_camera
# 0    A        shelton    WA            True  attack        False
# 1    W          aloha    OR           False  attack        False
# 2    H        wichita    KS           False   other        False
# 3    W  san francisco    CA            True  attack        False
# 4    H          evans    CO           False  attack        False

# %%
poverty_level.head()
# Out:
#   state             city  poverty_rate
# 0    AL       abanda cdp     78.800003
# 1    AL   abbeville city     29.100000
# 2    AL  adamsville city     25.500000
# 3    AL     addison town     30.700001
# 4    AL       akron town     42.000000

# %%
median_house_income.head()
# Out:
#   state             city  median_income
# 0    AL       Abanda CDP        11207.0
# 1    AL   Abbeville city        25615.0
# 2    AL  Adamsville city        42575.0
# 3    AL     Addison town        37083.0
# 4    AL       Akron town        21667.0

# %%
#showing the total number of people killed by race
plt.figure(figsize=(15,5))
sns.countplot(data=kill, x='race')
plt.title('Total number of people killed, by race',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Total number of people killed, by race')

# %%
# showing the number of people killed as a proportion of their respective race
race_list = ["A", "B", "H", "N", "O", "W"]
killed_perrace = []

for i in race_list:
    killings_c = kill.race.loc[(kill.race==i)].count()
    killed_perrace.append(killings_c)
    
print (killed_perrace)
# Out:
# [39, 618, 423, 31, 28, 1201]

# %%
# General age distribution
plt.figure(figsize=(15,5))
age_dist = sns.distplot(kill.age, bins= 40)
age_dist.set(xlabel='Age',ylabel='Count')
plt.title('Age distribution',fontsize=18)
# Out:
# C:\Users\layegh\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# Text(0.5, 1.0, 'Age distribution')

# %%
#merged = pd.merge (poverty_level , kill, on=['state','city'] , how='inner')
for index,row in poverty_level.iterrows():
    tempcity = row["city"]
    citysplit = tempcity.split(" ")
    if(citysplit[-1] == "cdp" or citysplit[-1] == "city" or  citysplit[-1] == "town" or citysplit[-1]=="village"): 
        del citysplit[-1] 
    tempstring = " ".join(citysplit)
    poverty_level.set_value(index,"city",tempstring)
poverty_level.city
# Out:
# C:\Users\layegh\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 0                    abanda
# 1                 abbeville
# 2                adamsville
# 3                   addison
# 4                     akron
# 5                 alabaster
# 6               albertville
# 7            alexander city
# 8                alexandria
# 9                aliceville
# 10                  allgood
# 11                  altoona
# 12                andalusia
# 13                 anderson
# 14                 anniston
# 15                     arab
# 16                  ardmore
# 17                     argo
# 18                   ariton
# 19                    arley
# 20                  ashford
# 21                  ashland
# 22                 ashville
# 23                   athens
# 24                   atmore
# 25                  attalla
# 26                   auburn
# 27             autaugaville
# 28                     avon
# 29                     axis
#                 ...
# 29298         south greeley
# 29299            south park
# 29300     star valley ranch
# 29301                 story
# 29302              sundance
# 29303              superior
# 29305                taylor
# 29306             ten sleep
# 29307         teton village
# 29308                thayne
# 29309           thermopolis
# 29310            torrington
# 29311           turnerville
# 29312                 upton
# 29313                  urie
# 29314           van tassell
# 29315               veteran
# 29316            vista west
# 29317             wamsutter
# 29318            warren afb
# 29319                washam
# 29320       westview circle
# 29321             wheatland
# 29322               whiting
# 29323                wilson
# 29324    woods landing-jelm
# 29325               worland
# 29326                wright
# 29327                 yoder
# 29328             y-o ranch
# Name: city, Length: 29128, dtype: object

# %%
kill.head()
# Out:
#                  name       date   manner_of_death       armed   age gender  \
# 0          Tim Elliot 2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#   race           city state  mental_illness  threat  body_camera
# 0    A        shelton    WA            True  attack        False
# 1    W          aloha    OR           False  attack        False
# 2    H        wichita    KS           False   other        False
# 3    W  san francisco    CA            True  attack        False
# 4    H          evans    CO           False  attack        False

# %%
#age distribution by race
three_races = kill.loc[(kill["race"] == "B") | (kill["race"] == "W") | (kill["race"] == "H")]
g = sns.FacetGrid(data=three_races, hue="race", aspect=3, size=4)
g.map(sns.kdeplot, "age", shade=True)
g.add_legend(title="Race")
g.set_ylabels("Count")
plt.title("Age distribution, by race", fontsize=17)
# Out:
# C:\Users\layegh\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning:
#
# The `size` paramter has been renamed to `height`; please update your code.
# Text(0.5, 1.0, 'Age distribution, by race')

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=kill, x=kill.state, order=kill['state'].value_counts().index)
plt.title("Number of police killings, by state", fontsize=27)
# Out:
# Text(0.5, 1.0, 'Number of police killings, by state')

# %%
area_list = list(race_by_city['state'].unique())
white=[]
black=[]
native_american=[]
asian=[]
hispanic=[]
for i in area_list:
    x=race_by_city[race_by_city["state"]==i]
    white.append(sum(x.white)/len(x))
    black.append(sum(x.black)/len(x))
    native_american.append(sum(x.native_american)/len(x))
    asian.append(sum(x.asian)/len(x))
    hispanic.append(sum(x.hispanic)/len(x))
f,ax=plt.subplots(figsize=(15,10))
sns.barplot(x=white,y=area_list,color="#8c001a", alpha=0.9,label="Whites")
sns.barplot(x=black,y=area_list, color= "#00fdd1", alpha=0.9, label="Blacks")
sns.barplot(x=native_american,y=area_list, color= "#2701d5", alpha=0.9, label="Native Americans")
sns.barplot(x=asian,y=area_list, color="#ffd62a", alpha=0.9, label="Asians")
sns.barplot(x=hispanic,y=area_list, color="#46a346", alpha=0.9, label="Hispanics")

ax.legend(ncol=2,loc="upper right",frameon=True)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='state', y='age',data=kill, order=['CA','TX','FL','AZ','OH','OK','NC','CO','GA','IL'])

# %%
#showing the race statistic at most dangrous states
racestate= race_by_city.groupby('state')[['state','white','black','asian','hispanic','native_american']].mean()
racestate['state']=racestate.index
racestate.loc[racestate['state'].isin(['CA','TX','FL','AZ','OH','OK','NC','CO','GA','IL'])]
# Out:
#            white      black     asian   hispanic  native_american state
# state
# AZ     59.929047   0.954545  0.726608  20.144567        28.589800    AZ
# CA     71.866295   2.692019  5.568206  29.649868         1.723087    CA
# CO     87.768341   0.917686  1.154804  17.898689         1.624891    CO
# FL     78.672501  13.370870  1.616739  16.529131         0.455435    FL
# GA     62.591534  30.633547  1.491534   6.415176         0.300319    GA
# IL     90.357056   4.704316  1.337454   5.170519         0.261814    IL
# NC     71.516510  20.402300  0.926252   6.412855         1.788092    NC
# OH     92.804070   3.959967  0.751495   2.130399         0.215033    OH
# OK     72.925781   3.376262  0.426467   5.696453        14.382129    OK
# TX     82.591934   5.879748  1.014760  39.364876         0.658867    TX

# %%
#observe the mental situation
plt.figure(figsize=(20,10))
sns.countplot(data=kill, x='mental_illness')

# %%
kill.groupby(['mental_illness','threat'])['mental_illness'].count()
# Out:
# mental_illness  threat
# False           attack          1148
#                 other            488
#                 undetermined     117
# True            attack           355
#                 other            219
#                 undetermined      13
# Name: mental_illness, dtype: int64

# %%
area_list = list(poverty_level['state'].unique())
poverty_ratio=[]
for i in area_list:
    x=poverty_level[poverty_level['state']== i]
    area_poverty_rate= sum(x.poverty_rate)/len(x)
    poverty_ratio.append(area_poverty_rate)
data_poverty_ratio = pd.DataFrame({'area_list': area_list , 'poverty_rate':poverty_ratio})
poverty_ratio_index=(data_poverty_ratio['poverty_rate'].sort_values(ascending=False)).index.values
sorted_poverty_ratio = data_poverty_ratio.reindex(poverty_ratio_index)

highschool_ratio=[]
for i in area_list:
    x = percentage_complete_highschool[percentage_complete_highschool['state']==i]
    complete_rate = sum(x.completed_hs)/len(x)
    highschool_ratio.append(complete_rate)
HS_Ratio = pd.DataFrame({'area_list': area_list , 'HighSchool_Rate': highschool_ratio})
HS_Ratio_index = (HS_Ratio['HighSchool_Rate'].sort_values(ascending = False )).index.values
sorted_HS_Ratio = HS_Ratio.reindex(HS_Ratio_index)
data=pd.concat([sorted_poverty_ratio,sorted_HS_Ratio["HighSchool_Rate"]],axis=1)
g = sns.jointplot(data.poverty_rate, data.HighSchool_Rate, kind="reg", size=7)
# Out:
# C:\Users\layegh\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning:
#
# The `size` paramter has been renamed to `height`; please update your code.

# %%
sorted_HS_Ratio.head()
# Out:
#    area_list  HighSchool_Rate
# 21        MA        92.404082
# 50        WY        92.100538
# 11        HI        91.665563
# 44        UT        91.617925
# 6         CT        91.591667

# %%
#f,ax1=plt.subplot(figsize=(20,10))
#data= pd.merge(HS_Ratio,data_poverty_ratio, on='city', how='inner')
poverty_level.head()
# Out:
#   state        city  poverty_rate
# 0    AL      abanda     78.800003
# 1    AL   abbeville     29.100000
# 2    AL  adamsville     25.500000
# 3    AL     addison     30.700001
# 4    AL       akron     42.000000

# %%
#plotting how the victims were armed
armed=kill.armed.value_counts()
plt.figure(figsize=(10,7))
sns.barplot(armed[:7].index,armed[:7].values)

# %%
#sorted_poverty_level = poverty_level.reindex(poverty_level_index)
area_list = list(poverty_level['state'].unique())
poverty_ratio=[]
#calculate the eaverage rate for each city in terms of their cities
for i in area_list: 
    x=poverty_level[poverty_level['state']== i]
    area_poverty_rate= sum(x.poverty_rate)/len(x)
    poverty_ratio.append(area_poverty_rate)
data_poverty_level = pd.DataFrame({'area_list': area_list , 'poverty_rate':poverty_ratio})
poverty_level_index = (data_poverty_level['poverty_rate'].sort_values(ascending = False )).index.values
data_poverty_level = data_poverty_level.reindex(poverty_level_index)
data_poverty_level.head(10)
plt.figure(figsize=(15,10))
g=sns.barplot(x=data_poverty_level.area_list,y=data_poverty_level.poverty_rate,data=data_poverty_level)
g.set(xlim=(0, 19)) #to see the top20
# Out:
# [(0, 19)]

# %%
highschool_ratio=[]
#calculate highschool rate for each state
for i in area_list:
    x = percentage_complete_highschool[percentage_complete_highschool['state']==i]
    complete_rate = sum(x.completed_hs)/len(x)
    highschool_ratio.append(complete_rate)
HS_Ratio = pd.DataFrame({'area_list': area_list , 'HighSchool_Rate': highschool_ratio})
HS_Ratio_index = (HS_Ratio['HighSchool_Rate'].sort_values(ascending = True )).index.values
sorted_HS_Ratio = HS_Ratio.reindex(HS_Ratio_index)
plt.figure(figsize=(15,10))
g=sns.barplot(x=sorted_HS_Ratio.area_list,y=sorted_HS_Ratio.HighSchool_Rate,data=sorted_HS_Ratio)
g.set(xlim=(0, 19)) #getting the top20
# Out:
# [(0, 19)]

# %%
pwd
# Out:
# 'C:\\Users\\layegh'
